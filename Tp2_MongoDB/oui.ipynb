# %%
def get_database():
    # Provide the mongodb atlas url to connect python to mongodb using pymongo
    CONNECTION_STRING = "mongodb+srv://leobatarda_db_user:NNIcYgtmVqMeOTkG@perfbase.d3rlvd9.mongodb.net/"
    # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
    from pymongo import MongoClient
    client = MongoClient(CONNECTION_STRING)
    # Create the database for our example (we will use the same database throughout the tutorial
    return client['perfbase_db']

# %%
get_database()
# Out:
# Database(MongoClient(host=['ac-welof6i-shard-00-00.d3rlvd9.mongodb.net:27017', 'ac-welof6i-shard-00-02.d3rlvd9.mongodb.net:27017', 'ac-welof6i-shard-00-01.d3rlvd9.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-j5jiz7-shard-0', tls=True), 'perfbase_db')

# %%
import requests
import json

r = requests.get('http://api.open-notify.org/iss-now.json')
data = r.json()
print(json.dumps(data, indent=4))
print(f"Latitude: {data['iss_position']['latitude']}, Longitude: {data['iss_position']['longitude']}")
print(f"Timestamp: {data['timestamp']}")
# Out:
# {
#     "iss_position": {
#         "longitude": "-78.2109",
#         "latitude": "-35.4293"
#     },
#     "message": "success",
#     "timestamp": 1768896994
# }
# Latitude: -35.4293, Longitude: -78.2109
# Timestamp: 1768896994

# %% [markdown]
# Chargez les donnees sur mongodb
